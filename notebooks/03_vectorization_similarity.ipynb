# %% [markdown]
# # 03 TF-IDF Vectorization and Cosine Similarity
#
# Fit the TF-IDF recommender and inspect recommendations.

# %%
import sys
from pathlib import Path

_nb = Path("notebooks/_project.py")
sys.path.insert(0, str(_nb.parent if _nb.exists() else Path("_project.py").parent))
from _project import setup

setup()

import pandas as pd
from app.services.ml.tfidf_recommender import MovieRecommender

catalog = pd.read_parquet('data/raw/tmdb_catalog.parquet')
recommender = MovieRecommender()
recommender.fit(catalog)
recommender.recommend('The Matrix', k=10, mode='title')
# Out:
# [{'tmdb_id': 19995,
#   'title': 'Avatar',
#   'score': 0.130195,
#   'overview': 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.',
#   'release_date': '2009-12-16',
#   'genres': ('Science Fiction', 'Action', 'Adventure'),
#   'poster_path': '/gKY6q7SjCkAU6FqvqWybDYgUKIF.jpg',
#   'vote_average': 7.606,
#   'popularity': 39.1025},
#  {'tmdb_id': 597,
#   'title': 'Titanic',
#   'score': 0.125473,
#   'overview': "101-year-old Rose DeWitt Bukater tells the story of her life aboard the Titanic, 84 years later. A young Rose boards the ship with her mother and fiancé. Meanwhile, Jack Dawson and Fabrizio De Rossi win third-class tickets aboard the ship. Rose tells the whole story from Titanic's departure through to its death—on its first and last voyage—on April 15, 1912.",
#   'release_date': '1997-12-18',
#   'genres': ('Drama', 'Romance'),
# ...

# %%
recommender.save('artifacts')
