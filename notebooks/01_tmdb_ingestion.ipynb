# %% [markdown]
# # 01 TMDB Ingestion
#
# Collect movie IDs from TMDB, enrich each movie with details, credits, genres, and keywords, then save a raw catalog.

# %%
import sys
from pathlib import Path

_nb = Path("notebooks/_project.py")
sys.path.insert(0, str(_nb.parent if _nb.exists() else Path("_project.py").parent))
from _project import setup

setup()

from app.services.ml.catalog_builder import TMDBCatalogBuilder

builder = TMDBCatalogBuilder()
catalog = builder.build_catalog(pages=10)
catalog.head()
# Out:
# Discovering TMDB movie IDs: 100%|██████████| 10/10 [00:09<00:00,  1.02it/s]
# Fetching enriched movie details: 100%|██████████| 200/200 [03:08<00:00,  1.06it/s]
#    tmdb_id             title  \
# 0  1339713         Obsession
# 1   936075           Michael
# 2   931285  Mortal Kombat II
# 3  1057265             Peddi
# 4  1275779    Disclosure Day
#
#                                             overview release_date  popularity  \
# 0  After breaking the mysterious "One Wish Willow...   2026-05-13    718.2017
# 1  The story of Michael Jackson, one of the most ...   2026-04-22    611.2146
# 2  The fan favorite champions—now joined by Johnn...   2026-05-06    611.0283
# 3  In 1980s rural Andhra Pradesh, a spirited vill...   2026-06-03    504.9155
# 4  If you found out we weren’t alone, if someone ...   2026-06-10    371.3022
#
#    vote_average  vote_count                               genres  \
# 0         7.918         780                   (Horror, Thriller)
# 1         8.629        2389                       (Music, Drama)
# 2         8.016        1346         (Action, Fantasy, Adventure)
# 3         6.800          40                      (Action, Drama)
# 4         6.877         362  (Action, Science Fiction, Thriller)
#
#                                             keywords  \
# 0  (obsession, supernatural, possession, wish, un...
# 1  (child abuse, sibling relationship, 1970s, abu...
# 2  (martial arts, magic, ninja fighter, gore, seq...
# 3   (sports, politics, cricket, 1980s, multi-sports)
# 4  (race against time, alien, alien invasion, met...
#
#                                                 cast            directors  \
# 0  (Michael Johnston, Inde Navarrette, Cooper Tom...      (Curry Barker,)
# 1  (Jaafar Jackson, Colman Domingo, Nia Long, Jul...     (Antoine Fuqua,)
# 2  (Karl Urban, Adeline Rudolph, Jessica McNamee,...     (Simon McQuoid,)
# 3  (Ram Charan, Janhvi Kapoor, Shiva Rajkumar, Ja...   (Buchi Babu Sana,)
# 4  (Emily Blunt, Josh O'Connor, Colin Firth, Colm...  (Steven Spielberg,)
#
#                         poster_path
# 0  /bRwnj8WEKBCvmfeUNOukJPwB43K.jpg
# 1  /zm0KAbOjlt9eR5y7vDiL2dEOwMl.jpg
# 2  /hwRdDFIhaEmpRgoki805YvyyjZf.jpg
# 3  /kJAJNNBYlbqAcpTDxBNnaILSMTy.jpg
# 4  /3o5YPjDGDTcTDL5ftDA9NwN9dLd.jpg

# %%
catalog.shape
# Out:
# (200, 12)

# %%
builder.save_catalog(catalog, 'data/raw/tmdb_catalog.parquet')
